# %%
from langchain_community.document_loaders import PyPDFLoader
loader=PyPDFLoader('attention.pdf')
docs=loader.load()
docs
# Out:
# incorrect startxref pointer(1)
# parsing for Object Streams
# found 0 objects within Object(2,0) whereas 100 expected
# found 0 objects within Object(202,0) whereas 100 expected
# found 0 objects within Object(321,0) whereas 100 expected
# found 0 objects within Object(1017,0) whereas 100 expected
# found 0 objects within Object(1646,0) whereas 100 expected
# found 0 objects within Object(1647,0) whereas 100 expected
# found 0 objects within Object(1648,0) whereas 100 expected
# found 0 objects within Object(1649,0) whereas 100 expected
# found 0 objects within Object(1650,0) whereas 100 expected
# found 0 objects within Object(1651,0) whereas 100 expected
# found 0 objects within Object(2251,0) whereas 100 expected
# found 0 objects within Object(2787,0) whereas 100 expected
# found 0 objects within Object(2788,0) whereas 100 expected
# found 0 objects within Object(2789,0) whereas 100 expected
# found 0 objects within Object(2790,0) whereas 100 expected
# found 0 objects within Object(2791,0) whereas 100 expected
# found 0 objects within Object(3804,0) whereas 100 expected
# found 0 objects within Object(3805,0) whereas 100 expected
# found 0 objects within Object(3806,0) whereas 100 expected
# found 0 objects within Object(3807,0) whereas 100 expected
# found 0 objects within Object(3808,0) whereas 100 expected
# found 0 objects within Object(4375,0) whereas 100 expected
# found 0 objects within Object(4876,0) whereas 100 expected
# found 0 objects within Object(4877,0) whereas 100 expected
# found 0 objects within Object(4878,0) whereas 100 expected
# found 0 objects within Object(4879,0) whereas 100 expected
# found 0 objects within Object(4880,0) whereas 100 expected
# found 0 objects within Object(5829,0) whereas 100 expected
# found 0 objects within Object(5830,0) whereas 100 expected
# found 0 objects within Object(5831,0) whereas 100 expected
# found 0 objects within Object(5832,0) whereas 100 expected
# found 0 objects within Object(5833,0) whereas 100 expected
# found 0 objects within Object(5930,0) whereas 43 expected
# [Document(metadata={'producer': 'pdfTeX-1.40.25', 'creator': 'LaTeX with hyperref', 'creationdate': '2024-04-10T21:11:43+00:00', 'author': '', 'keywords': '', 'moddate': '2024-04-10T21:11:43+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.25 (TeX Live 2023) kpathsea version 6.3.5', 'subject': '', 'title': '', 'trapped': '/False', 'source': 'attention.pdf', 'total_pages': 15, 'page': 0, 'page_label': '1'}, page_content=''),
#  Document(metadata={'producer': 'pdfTeX-1.40.25', 'creator': 'LaTeX with hyperref', 'creationdate': '2024-04-10T21:11:43+00:00', 'author': '', 'keywords': '', 'moddate': '2024-04-10T21:11:43+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.25 (TeX Live 2023) kpathsea version 6.3.5', 'subject': '', 'title': '', 'trapped': '/False', 'source': 'attention.pdf', 'total_pages': 15, 'page': 1, 'page_label': '2'}, page_content=''),
#  Document(metadata={'producer': 'pdfTeX-1.40.25', 'creator': 'LaTeX with hyperref', 'creationdate': '2024-04-10T21:11:43+00:00', 'author': '', 'keywords': '', 'moddate': '2024-04-10T21:11:43+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.25 (TeX Live 2023) kpathsea version 6.3.5', 'subject': '', 'title': '', 'trapped': '/False', 'source': 'attention.pdf', 'total_pages': 15, 'page': 2, 'page_label': '3'}, page_content=''),
#  Document(metadata={'producer': 'pdfTeX-1.40.25', 'creator': 'LaTeX with hyperref', 'creationdate': '2024-04-10T21:11:43+00:00', 'author': '', 'keywords': '', 'moddate': '2024-04-10T21:11:43+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.25 (TeX Live 2023) kpathsea version 6.3.5', 'subject': '', 'title': '', 'trapped': '/False', 'source': 'attention.pdf', 'total_pages': 15, 'page': 3, 'page_label': '4'}, page_content=''),
#  Document(metadata={'producer': 'pdfTeX-1.40.25', 'creator': 'LaTeX with hyperref', 'creationdate': '2024-04-10T21:11:43+00:00', 'author': '', 'keywords': '', 'moddate': '2024-04-10T21:11:43+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.25 (TeX Live 2023) kpathsea version 6.3.5', 'subject': '', 'title': '', 'trapped': '/False', 'source': 'attention.pdf', 'total_pages': 15, 'page': 4, 'page_label': '5'}, page_content=''),
#  Document(metadata={'producer': 'pdfTeX-1.40.25', 'creator': 'LaTeX with hyperref', 'creationdate': '2024-04-10T21:11:43+00:00', 'author': '', 'keywords': '', 'moddate': '2024-04-10T21:11:43+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.25 (TeX Live 2023) kpathsea version 6.3.5', 'subject': '', 'title': '', 'trapped': '/False', 'source': 'attention.pdf', 'total_pages': 15, 'page': 5, 'page_label': '6'}, page_content=''),
#  Document(metadata={'producer': 'pdfTeX-1.40.25', 'creator': 'LaTeX with hyperref', 'creationdate': '2024-04-10T21:11:43+00:00', 'author': '', 'keywords': '', 'moddate': '2024-04-10T21:11:43+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.25 (TeX Live 2023) kpathsea version 6.3.5', 'subject': '', 'title': '', 'trapped': '/False', 'source': 'attention.pdf', 'total_pages': 15, 'page': 6, 'page_label': '7'}, page_content=''),
#  Document(metadata={'producer': 'pdfTeX-1.40.25', 'creator': 'LaTeX with hyperref', 'creationdate': '2024-04-10T21:11:43+00:00', 'author': '', 'keywords': '', 'moddate': '2024-04-10T21:11:43+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.25 (TeX Live 2023) kpathsea version 6.3.5', 'subject': '', 'title': '', 'trapped': '/False', 'source': 'attention.pdf', 'total_pages': 15, 'page': 7, 'page_label': '8'}, page_content=''),
#  Document(metadata={'producer': 'pdfTeX-1.40.25', 'creator': 'LaTeX with hyperref', 'creationdate': '2024-04-10T21:11:43+00:00', 'author': '', 'keywords': '', 'moddate': '2024-04-10T21:11:43+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.25 (TeX Live 2023) kpathsea version 6.3.5', 'subject': '', 'title': '', 'trapped': '/False', 'source': 'attention.pdf', 'total_pages': 15, 'page': 8, 'page_label': '9'}, page_content=''),
#  Document(metadata={'producer': 'pdfTeX-1.40.25', 'creator': 'LaTeX with hyperref', 'creationdate': '2024-04-10T21:11:43+00:00', 'author': '', 'keywords': '', 'moddate': '2024-04-10T21:11:43+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.25 (TeX Live 2023) kpathsea version 6.3.5', 'subject': '', 'title': '', 'trapped': '/False', 'source': 'attention.pdf', 'total_pages': 15, 'page': 9, 'page_label': '10'}, page_content=''),
#  Document(metadata={'producer': 'pdfTeX-1.40.25', 'creator': 'LaTeX with hyperref', 'creationdate': '2024-04-10T21:11:43+00:00', 'author': '', 'keywords': '', 'moddate': '2024-04-10T21:11:43+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.25 (TeX Live 2023) kpathsea version 6.3.5', 'subject': '', 'title': '', 'trapped': '/False', 'source': 'attention.pdf', 'total_pages': 15, 'page': 10, 'page_label': '11'}, page_content=''),
#  Document(metadata={'producer': 'pdfTeX-1.40.25', 'creator': 'LaTeX with hyperref', 'creationdate': '2024-04-10T21:11:43+00:00', 'author': '', 'keywords': '', 'moddate': '2024-04-10T21:11:43+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.25 (TeX Live 2023) kpathsea version 6.3.5', 'subject': '', 'title': '', 'trapped': '/False', 'source': 'attention.pdf', 'total_pages': 15, 'page': 11, 'page_label': '12'}, page_content=''),
#  Document(metadata={'producer': 'pdfTeX-1.40.25', 'creator': 'LaTeX with hyperref', 'creationdate': '2024-04-10T21:11:43+00:00', 'author': '', 'keywords': '', 'moddate': '2024-04-10T21:11:43+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.25 (TeX Live 2023) kpathsea version 6.3.5', 'subject': '', 'title': '', 'trapped': '/False', 'source': 'attention.pdf', 'total_pages': 15, 'page': 12, 'page_label': '13'}, page_content=''),
#  Document(metadata={'producer': 'pdfTeX-1.40.25', 'creator': 'LaTeX with hyperref', 'creationdate': '2024-04-10T21:11:43+00:00', 'author': '', 'keywords': '', 'moddate': '2024-04-10T21:11:43+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.25 (TeX Live 2023) kpathsea version 6.3.5', 'subject': '', 'title': '', 'trapped': '/False', 'source': 'attention.pdf', 'total_pages': 15, 'page': 13, 'page_label': '14'}, page_content=''),
#  Document(metadata={'producer': 'pdfTeX-1.40.25', 'creator': 'LaTeX with hyperref', 'creationdate': '2024-04-10T21:11:43+00:00', 'author': '', 'keywords': '', 'moddate': '2024-04-10T21:11:43+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.25 (TeX Live 2023) kpathsea version 6.3.5', 'subject': '', 'title': '', 'trapped': '/False', 'source': 'attention.pdf', 'total_pages': 15, 'page': 14, 'page_label': '15'}, page_content='')]

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter
text_splitter=RecursiveCharacterTextSplitter(chunk_size=1000,chunk_overlap=200)
text_splitter.split_documents(docs)[:5]
documents = text_splitter.split_documents(docs)
documents[:5]
# Out:
# []

# %%
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.vectorstores import Chroma
# embeddings = HuggingFaceEmbeddings(model_name="BAAI/bge-small-en")
db=Chroma.from_documents(documents[:15], HuggingFaceEmbeddings(model_name="BAAI/bge-base-en"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\9luis\OneDrive\Desktop\Langchain\venv\Lib\site-packages\chromadb\api\models\CollectionCommon.py:90, in validation_context.<locals>.decorator.<locals>.wrapper(self, *args, **kwargs)
#      89 try:
# ---> 90     return func(self, *args, **kwargs)
#      91 except Exception as e:
#
# File c:\Users\9luis\OneDrive\Desktop\Langchain\venv\Lib\site-packages\chromadb\api\models\CollectionCommon.py:389, in CollectionCommon._validate_and_prepare_upsert_request(self, ids, embeddings, metadatas, documents, images, uris)
#     373 @validation_context("upsert")
#     374 def _validate_and_prepare_upsert_request(
#     375     self,
#    (...)
#     387 ) -> UpsertRequest:
#     388     # Unpack
# --> 389     upsert_records = normalize_insert_record_set(
#     390         ids=ids,
#     391         embeddings=embeddings,
#     392         metadatas=metadatas,
#     393         documents=documents,
#     394         images=images,
#     395         uris=uris,
#     396     )
#     398     # Validate
#
# File c:\Users\9luis\OneDrive\Desktop\Langchain\venv\Lib\site-packages\chromadb\api\types.py:187, in normalize_insert_record_set(ids, embeddings, metadatas, documents, images, uris)
#     184 """
#     185 Unpacks and normalizes the fields of an InsertRecordSet.
#     186 """
# --> 187 base_record_set = normalize_base_record_set(
#     188     embeddings=embeddings, documents=documents, images=images, uris=uris
#     189 )
#     191 return InsertRecordSet(
#     192     ids=cast(IDs, maybe_cast_one_to_many(ids)),
#     193     metadatas=maybe_cast_one_to_many(metadatas),
#    (...)
#     197     uris=base_record_set["uris"],
#     198 )
#
# File c:\Users\9luis\OneDrive\Desktop\Langchain\venv\Lib\site-packages\chromadb\api\types.py:164, in normalize_base_record_set(embeddings, documents, images, uris)
#     159 """
#     160 Unpacks and normalizes the fields of a BaseRecordSet.
#     161 """
#     163 return BaseRecordSet(
# --> 164     embeddings=normalize_embeddings(embeddings),
#     165     documents=maybe_cast_one_to_many(documents),
#     166     images=maybe_cast_one_to_many(images),
#     167     uris=maybe_cast_one_to_many(uris),
#     168 )
#
# File c:\Users\9luis\OneDrive\Desktop\Langchain\venv\Lib\site-packages\chromadb\api\types.py:61, in normalize_embeddings(target)
#      60 if len(target) == 0:
# ---> 61     raise ValueError(
#      62         f"Expected Embedings to be non-empty list or numpy array, got {target}"
#      63     )
#      65 if isinstance(target, list):
#      66     # One PyEmbedding
#
# ValueError: Expected Embedings to be non-empty list or numpy array, got []
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 4
#       2 from langchain_community.vectorstores import Chroma
#       3 # embeddings = HuggingFaceEmbeddings(model_name="BAAI/bge-small-en")
# ----> 4 db=Chroma.from_documents(documents[:15], HuggingFaceEmbeddings(model_name="BAAI/bge-base-en"))
#
# File c:\Users\9luis\OneDrive\Desktop\Langchain\venv\Lib\site-packages\langchain_community\vectorstores\chroma.py:887, in Chroma.from_documents(cls, documents, embedding, ids, collection_name, persist_directory, client_settings, client, collection_metadata, **kwargs)
#     885 texts = [doc.page_content for doc in documents]
#     886 metadatas = [doc.metadata for doc in documents]
# --> 887 return cls.from_texts(
#     888     texts=texts,
#     889     embedding=embedding,
#     890     metadatas=metadatas,
#     891     ids=ids,
#     892     collection_name=collection_name,
#     893     persist_directory=persist_directory,
#     894     client_settings=client_settings,
#     895     client=client,
#     896     collection_metadata=collection_metadata,
#     897     **kwargs,
#     898 )
#
# File c:\Users\9luis\OneDrive\Desktop\Langchain\venv\Lib\site-packages\langchain_community\vectorstores\chroma.py:843, in Chroma.from_texts(cls, texts, embedding, metadatas, ids, collection_name, persist_directory, client_settings, client, collection_metadata, **kwargs)
#     835     from chromadb.utils.batch_utils import create_batches
#     837     for batch in create_batches(
#     838         api=chroma_collection._client,  # type: ignore[has-type]
#     839         ids=ids,
#     840         metadatas=metadatas,  # type: ignore[arg-type]
#     841         documents=texts,
#     842     ):
# --> 843         chroma_collection.add_texts(
#     844             texts=batch[3] if batch[3] else [],
#     845             metadatas=batch[2] if batch[2] else None,  # type: ignore[arg-type]
#     846             ids=batch[0],
#     847         )
#     848 else:
#     849     chroma_collection.add_texts(texts=texts, metadatas=metadatas, ids=ids)
#
# File c:\Users\9luis\OneDrive\Desktop\Langchain\venv\Lib\site-packages\langchain_community\vectorstores\chroma.py:326, in Chroma.add_texts(self, texts, metadatas, ids, **kwargs)
#     320         self._collection.upsert(
#     321             embeddings=embeddings_without_metadatas,  # type: ignore[arg-type]
#     322             documents=texts_without_metadatas,
#     323             ids=ids_without_metadatas,
#     324         )
#     325 else:
# --> 326     self._collection.upsert(
#     327         embeddings=embeddings,  # type: ignore[arg-type]
#     328         documents=texts,
#     329         ids=ids,
#     330     )
#     331 return ids
#
# File c:\Users\9luis\OneDrive\Desktop\Langchain\venv\Lib\site-packages\chromadb\api\models\Collection.py:335, in Collection.upsert(self, ids, embeddings, metadatas, documents, images, uris)
#     310 def upsert(
#     311     self,
#     312     ids: OneOrMany[ID],
#    (...)
#     322     uris: Optional[OneOrMany[URI]] = None,
#     323 ) -> None:
#     324     """Update the embeddings, metadatas or documents for provided ids, or create them if they don't exist.
#     325
#     326     Args:
#    (...)
#     333         None
#     334     """
# --> 335     upsert_request = self._validate_and_prepare_upsert_request(
#     336         ids=ids,
#     337         embeddings=embeddings,
#     338         metadatas=metadatas,
#     339         documents=documents,
#     340         images=images,
#     341         uris=uris,
#     342     )
#     344     self._client._upsert(
#     345         collection_id=self.id,
#     346         ids=upsert_request["ids"],
#    (...)
#     352         database=self.database,
#     353     )
#
# File c:\Users\9luis\OneDrive\Desktop\Langchain\venv\Lib\site-packages\chromadb\api\models\CollectionCommon.py:93, in validation_context.<locals>.decorator.<locals>.wrapper(self, *args, **kwargs)
#      91 except Exception as e:
#      92     msg = f"{str(e)} in {name}."
# ---> 93     raise type(e)(msg).with_traceback(e.__traceback__)
#
# File c:\Users\9luis\OneDrive\Desktop\Langchain\venv\Lib\site-packages\chromadb\api\models\CollectionCommon.py:90, in validation_context.<locals>.decorator.<locals>.wrapper(self, *args, **kwargs)
#      87 @functools.wraps(func)
#      88 def wrapper(self: Any, *args: Any, **kwargs: Any) -> T:
#      89     try:
# ---> 90         return func(self, *args, **kwargs)
#      91     except Exception as e:
#      92         msg = f"{str(e)} in {name}."
#
# File c:\Users\9luis\OneDrive\Desktop\Langchain\venv\Lib\site-packages\chromadb\api\models\CollectionCommon.py:389, in CollectionCommon._validate_and_prepare_upsert_request(self, ids, embeddings, metadatas, documents, images, uris)
#     373 @validation_context("upsert")
#     374 def _validate_and_prepare_upsert_request(
#     375     self,
#    (...)
#     387 ) -> UpsertRequest:
#     388     # Unpack
# --> 389     upsert_records = normalize_insert_record_set(
#     390         ids=ids,
#     391         embeddings=embeddings,
#     392         metadatas=metadatas,
#     393         documents=documents,
#     394         images=images,
#     395         uris=uris,
#     396     )
#     398     # Validate
#     399     validate_insert_record_set(record_set=upsert_records)
#
# File c:\Users\9luis\OneDrive\Desktop\Langchain\venv\Lib\site-packages\chromadb\api\types.py:187, in normalize_insert_record_set(ids, embeddings, metadatas, documents, images, uris)
#     171 def normalize_insert_record_set(
#     172     ids: OneOrMany[ID],
#     173     embeddings: Optional[
#    (...)
#     182     uris: Optional[OneOrMany[URI]] = None,
#     183 ) -> InsertRecordSet:
#     184     """
#     185     Unpacks and normalizes the fields of an InsertRecordSet.
#     186     """
# --> 187     base_record_set = normalize_base_record_set(
#     188         embeddings=embeddings, documents=documents, images=images, uris=uris
#     189     )
#     191     return InsertRecordSet(
#     192         ids=cast(IDs, maybe_cast_one_to_many(ids)),
#     193         metadatas=maybe_cast_one_to_many(metadatas),
#    (...)
#     197         uris=base_record_set["uris"],
#     198     )
#
# File c:\Users\9luis\OneDrive\Desktop\Langchain\venv\Lib\site-packages\chromadb\api\types.py:164, in normalize_base_record_set(embeddings, documents, images, uris)
#     153 def normalize_base_record_set(
#     154     embeddings: Optional[Union[OneOrMany[Embedding], OneOrMany[PyEmbedding]]] = None,
#     155     documents: Optional[OneOrMany[Document]] = None,
#     156     images: Optional[OneOrMany[Image]] = None,
#     157     uris: Optional[OneOrMany[URI]] = None,
#     158 ) -> BaseRecordSet:
#     159     """
#     160     Unpacks and normalizes the fields of a BaseRecordSet.
#     161     """
#     163     return BaseRecordSet(
# --> 164         embeddings=normalize_embeddings(embeddings),
#     165         documents=maybe_cast_one_to_many(documents),
#     166         images=maybe_cast_one_to_many(images),
#     167         uris=maybe_cast_one_to_many(uris),
#     168     )
#
# File c:\Users\9luis\OneDrive\Desktop\Langchain\venv\Lib\site-packages\chromadb\api\types.py:61, in normalize_embeddings(target)
#      58     return None
#      60 if len(target) == 0:
# ---> 61     raise ValueError(
#      62         f"Expected Embedings to be non-empty list or numpy array, got {target}"
#      63     )
#      65 if isinstance(target, list):
#      66     # One PyEmbedding
#      67     if isinstance(target[0], (int, float)) and not isinstance(target[0], bool):
#
# ValueError: Expected Embedings to be non-empty list or numpy array, got [] in upsert.

# %%
query="What is attention is all you need"
result=db.similarity_search(query)
result[0].page_content

# %%
from langchain_community.vectorstores import FAISS
db=FAISS.from_documents(documents[:20], HuggingFaceEmbeddings())
